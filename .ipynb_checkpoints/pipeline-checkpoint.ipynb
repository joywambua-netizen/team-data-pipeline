# %% [markdown]
# DATA PIPELINE ACTION
#
# Procedure:
#
# Creation of a pandas DataFrame
#
# 1.Create a pandas DataFrame
#
# Descriptive statistics
#
# 1. Getting the information
#
# 2. Getting the sum
#
# 3. Getting the average
#
#
# Explanation:
#
# Summary
#
# 1. This data pipeline allows different members to contribute while working on the same Dataset to create a final merged version.
#
# 2. It shows changes made by different members.
#
# 3. It also allows access to previous versions prior to any changes made.
