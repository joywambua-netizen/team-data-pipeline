# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd
import numpy as np

# Initial dataset for our group project
data = {
    'Product': ['Item A', 'Item B', 'Item C', 'Item D'],
    'Sales_Units': [120, 250, 95, 310],
    'Price_KES': [1500, 2200, 1800, 2500],
    'Status': ['Delivered', 'Pending', 'Shipped', 'Delivered']
}

df = pd.DataFrame(data)
print("Initial DataFrame created successfully!")
df
# Out:
# Initial DataFrame created successfully!
#   Product  Sales_Units  Price_KES     Status
# 0  Item A          120       1500  Delivered
# 1  Item B          250       2200    Pending
# 2  Item C           95       1800    Shipped
# 3  Item D          310       2500  Delivered

# %%
#to get the information
print(df.info())
print(df.describe())
#to get  total sum
print(df.sum())
#to get the avarage
# print(df.mean())S
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Product      4 non-null      str
#  1   Sales_Units  4 non-null      int64
#  2   Price_KES    4 non-null      int64
#  3   Status       4 non-null      str
# dtypes: int64(2), str(2)
# memory usage: 260.0 bytes
# None
#        Sales_Units    Price_KES
# count     4.000000     4.000000
# mean    193.750000  2000.000000
# std     103.067534   439.696865
# min      95.000000  1500.000000
# 25%     113.750000  1725.000000
# 50%     185.000000  2000.000000
# 75%     265.000000  2275.000000
# max     310.000000  2500.000000
# Product                Item AItem BItem CItem D
# Sales_Units                                 775
# Price_KES                                  8000
# Status         DeliveredPendingShippedDelivered
# dtype: object
