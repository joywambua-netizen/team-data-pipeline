# %%
print("Hello")
# Out:
# Running cells with 'Python 3.12.10' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/ADMIN/AppData/Local/Microsoft/WindowsApps/python3.12.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import pandas as pd
import numpy as np

# Initial dataset for our group project
data = {
    'Product': ['Item A', 'Item B', 'Item C', 'Item D'],
    'Sales_Units': [120, 250, 95, 310],
    'Price_KES': [1500, 2200, 1800, 2500],
    'Status': ['Delivered', 'Pending', 'Shipped', 'Delivered']
}

df = pd.DataFrame(data)
print("Initial DataFrame created successfully!")
df

# %%
#to get the information
print(df.info())
print(df.describe())
#to get  total sum
print(df.sum())
#to get the avarage
# print(df.mean())S

# %% [markdown]
# EXPLANATION MARKDOWN
#
# Procedure:
#
# 1. Creation of a pandas DataFrame
#
# Descriptive statistics:
#
# 1. Obtaining information:
#    -Standard deviation
#    -minimum value
#    -maximum value
#    -data types
#
# 2. Getting the sum
#   -number of items sold(a, b, c, d)
#   -total sales
#
# 3. Getting the average
#
# Explanation:
#
# Summary
#
# 1. This data pipeline allows different members to contribute while working on the same Dataset to create a final merged version.
#
# 2. It shows the contributions made by each member.
#
# 3. It provides access to both the original and altered versions of the same project.
